# %%
#!pip install pymongo
#!pip install pytrends
#!pip install mongoengine

# %%
import pymongo

# %%
from pymongo import MongoClient

client = pymongo.MongoClient('mongodb://admin:P!per2013@cluster0-3gkzc.mongodb.net/test')
db = client.test
db.list_collection_names()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-33-193d68d566d6> in <module>()
#       3 client = pymongo.MongoClient('mongodb://admin:P!per2013@cluster0-3gkzc.mongodb.net/test')
#       4 db = client.test
# ----> 5 db.list_collection_names()
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\database.py in list_collection_names(self, session)
#     688         return [result["name"]
#     689                 for result in self.list_collections(session=session,
# --> 690                                                     nameOnly=True)]
#     691
#     692     def collection_names(self, include_system_collections=True,
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\database.py in list_collections(self, session, **kwargs)
#     672                      or ReadPreference.PRIMARY)
#     673         with self.__client._socket_for_reads(
# ...

# %%
from pymongo import MongoClient

client = pymongo.MongoClient("mongodb://root:P!per2013@104.248.208.74/test")
db = client.test
db.list_collection_names()

# %%
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-32-cf3ed68fcf38> in <module>()
# ----> 1 db.list_collection_names()
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\database.py in list_collection_names(self, session)
#     688         return [result["name"]
#     689                 for result in self.list_collections(session=session,
# --> 690                                                     nameOnly=True)]
#     691
#     692     def collection_names(self, include_system_collections=True,
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\database.py in list_collections(self, session, **kwargs)
#     672                      or ReadPreference.PRIMARY)
#     673         with self.__client._socket_for_reads(
# --> 674                 read_pref) as (sock_info, slave_okay):
#     675             return self._list_collections(
# ...

# %%
tc = db.get_collection('admin')
tc.index_information()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-14-14503ef18fde> in <module>()
#       1 tc = db.get_collection('admin')
# ----> 2 tc.index_information()
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\collection.py in index_information(self, session)
#    2192            Added ``session`` parameter.
#    2193         """
# -> 2194         cursor = self.list_indexes(session=session)
#    2195         info = {}
#    2196         for index in cursor:
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\collection.py in list_indexes(self, session)
#    2137                                  read_preference=ReadPreference.PRIMARY)
#    2138         sock_ctx, read_pref = self._socket_for_primary_reads(session)
# -> 2139         with sock_ctx as (sock_info, slave_ok):
#    2140             cmd = SON([("listIndexes", self.__name), ("cursor", {})])
# ...

# %%
from importlib import reload

import sys
sys.path.append('/anaconda/')
import config

reload(config)

config.fundamentals_db_do
# Out:
# {'DB_NAME': 'fundamental',
#  'EXCEL_DIR_PATH': 'E:/Dropbox/Dropbox/DATA/Fundamentals/',
#  'HOST': 'mysql-rds.cy2te0eq5wrm.us-west-2.rds.amazonaws.com',
#  'IP': '104.248.208.74',
#  'PASSWD': 'P!per2013',
#  'PORT': 3306,
#  'USER': 'root'}

# %%
from importlib import reload
from __future__ import print_function

import pandas as pd
import numpy as np

import pymongo
from pytrends.request import TrendReq



import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

import os

path_to_data = 'E:/Dropbox/Dropbox/alphascientist/googletrends/'

## NOTE: Add paths to dependencies on any machine being used here.  Invalid paths will be silently ignored  
import sys
sys.path.append('/anaconda/')
import config

sys.path.append(config.REPO_ROOT+'data/') #Chad: Home
#from schemas import ib_records,sbl,fundamentals
from schemas import fundamentals
from prices.eod import read


sys.path.append(config.REPO_ROOT+'symphony/') #Chad: Home
from symphony import data_utils,Scorecard

begin_date = '2012-01-01'
end_date = None #'2018-04-01'

folder = ''
# Out:
# C:\Anaconda2\envs\blog\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
master = pd.read_csv(config.UNIVERSE,index_col='symbol',encoding = "ISO-8859-1")
symbols = list(master[(master.active==True) & (master.type=='CEF')].index.unique())

# %%
search_terms = ['$'+s for s in symbols]
search_terms
# Out:
# ['$CUBA',
#  '$FXBY',
#  '$ACG',
#  '$ACP',
#  '$ACV',
#  '$ARDC',
#  '$ADX',
#  '$AFB',
#  '$AFT',
#  '$AGC',
#  '$AGD',
#  '$AIF',
#  '$AKP',
#  '$AOD',
#  '$APB',
#  '$APF',
#  '$ASG',
#  '$AVK',
#  '$AWF',
#  '$AWP',
#  '$BAF',
#  '$BBF',
#  '$BBK',
#  '$BBN',
#  '$BCX',
#  '$BCV',
#  '$BDJ',
#  '$BFK',
#  '$BFO',
#  '$BFY',
#  '$BFZ',
#  '$BGB',
#  '$BGH',
#  '$BGIO',
#  '$BGR',
#  '$BGT',
#  '$BGY',
#  '$BHK',
#  '$BHV',
#  '$BIF',
#  '$BIT',
#  '$BJZ',
#  '$BKK',
#  '$BKN',
#  '$BKT',
#  '$BLE',
#  '$BLH',
#  '$BLJ',
#  '$BLW',
#  '$BME',
#  '$BNJ',
#  '$BNY',
#  '$BOE',
#  '$BPK',
#  '$BQH',
#  '$BSD',
#  '$BSE',
#  '$BSL',
#  '$BST',
#  '$BTA',
#  '$BTO',
#  '$BTT',
#  '$BTZ',
#  '$BUI',
#  '$BWG',
#  '$BXMX',
#  '$BYM',
#  '$BZM',
#  '$CAF',
#  '$CBA',
#  '$CBH',
#  '$CCA',
#  '$CCD',
#  '$CEE',
#  '$CEF',
#  '$CEM',
#  '$CEN',
#  '$CEV',
#  '$CGO',
#  '$CHI',
#  '$CHW',
#  '$CHY',
#  '$CIF',
#  '$CII',
#  '$CIK',
#  '$CMU',
#  '$CSQ',
#  '$CTR',
#  '$CXE',
#  '$CXH',
# ...

# %%
sample_search = ['$AAPL','$TSLA'] 
pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(sample_search, cat=0, geo='', gprop='')

# %%
df = pytrends.get_historical_interest(sample_search)

# %%
db.create_collection('foo')
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-25-2db563348542> in <module>()
# ----> 1 db.create_collection('foo')
#
# C:\Anaconda2\envs\blog\lib\site-packages\pymongo\database.py in create_collection(self, name, codec_options, read_preference, write_concern, read_concern, session, **kwargs)
#     361            Removed deprecated argument: options
#     362         """
# --> 363         with self.__client._tmp_session(session) as s:
#     364             if name in self.list_collection_names(session=s):
#     365                 raise CollectionInvalid("collection %s already exists" % name)
#
# C:\Anaconda2\envs\blog\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
# ...

# %%
db.list_collection_names()

# %%
pytrends.get_historical_interest(sample_search, year_start=2018, month_start=1, day_start=1, hour_start=0, year_end=2018, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pytrends.get_historical_interest(['$AAPL'])
# Out:
#                      $AAPL  isPartial
# date
# 2018-01-01 00:00:00     18      False
# 2018-01-01 01:00:00      0      False
# 2018-01-01 02:00:00      0      False
# 2018-01-01 03:00:00     65      False
# 2018-01-01 04:00:00      0      False
# 2018-01-01 05:00:00      0      False
# 2018-01-01 06:00:00      0      False
# 2018-01-01 07:00:00      0      False
# 2018-01-01 08:00:00      0      False
# 2018-01-01 09:00:00      0      False
# 2018-01-01 10:00:00      0      False
# 2018-01-01 11:00:00     33      False
# 2018-01-01 12:00:00      0      False
# 2018-01-01 13:00:00      0      False
# 2018-01-01 14:00:00      0      False
# 2018-01-01 15:00:00     13      False
# 2018-01-01 16:00:00     24      False
# 2018-01-01 17:00:00     12      False
# 2018-01-01 18:00:00     12      False
# 2018-01-01 19:00:00      0      False
# 2018-01-01 20:00:00     27      False
# 2018-01-01 21:00:00     29      False
# 2018-01-01 22:00:00      0      False
# ...

# %%
pytrends.related_topics()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-cbed80715657> in <module>()
# ----> 1 pytrends.related_topics('$AAPL')
#
# TypeError: related_topics() takes 1 positional argument but 2 were given
